# %% [markdown]
# # PySpark + CockroachDB Analytical Notebook

# %% [markdown]
# ## 1. Import Required Libraries
# We begin by importing PySpark libraries and loading the `.env` variables containing CockroachDB and MongoDB credentials.

# %%
import os
from dotenv import load_dotenv
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, desc, countDistinct, max as spark_max, min as spark_min, explode

# Load environment variables from .env
load_dotenv()

print(" COCKROACH_USER:", os.getenv("COCKROACH_USER"))
print(" COCKROACH_PASS:", os.getenv("COCKROACH_PASS"))
print(" COCKROACH_HOST:", os.getenv("COCKROACH_HOST"))
print(" COCKROACH_PORT:", os.getenv("COCKROACH_PORT"))
print(" MONGO URI:", os.getenv("MONGO_ATLAS_URI"))
# Out:
#  COCKROACH_USER: shubh
#  COCKROACH_PASS: nrTPuxNNk9Oggf1lCXDkYw
#  COCKROACH_HOST: bowing-slime-10451.j77.aws-ap-south-1.cockroachlabs.cloud
#  COCKROACH_PORT: 26257
#  MONGO URI: mongodb+srv://shbpndr:CrVz9nzipaLOZFVk@sounds-similar.8sd8tnl.mongodb.net/

# %% [markdown]
# ## 2. Initialize Spark Session
# We initialize the Spark session and configure the required JDBC driver for CockroachDB.

# %%
spark = SparkSession.builder \
    .appName("CockroachDB_PySpark_Project") \
    .config("spark.jars.packages", "org.postgresql:postgresql:42.2.18") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.56.1:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CockroachDB_PySpark_Project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 3. CockroachDB Connection Properties
# We read the CockroachDB credentials from environment variables and build the JDBC connection string.

# %%
COCKROACH_USER = os.getenv("COCKROACH_USER")
COCKROACH_PASS = os.getenv("COCKROACH_PASS")
COCKROACH_HOST = os.getenv("COCKROACH_HOST")
COCKROACH_PORT = os.getenv("COCKROACH_PORT")
DATABASE_NAME = "music"

jdbc_url = f"jdbc:postgresql://{COCKROACH_HOST}:{COCKROACH_PORT}/{DATABASE_NAME}?sslmode=require"

connection_properties = {
    "user": COCKROACH_USER,
    "password": COCKROACH_PASS,
    "driver": "org.postgresql.Driver"
}

# %% [markdown]
# ## 4. Load Tables into DataFrames
# We load all four tables into Spark DataFrames for processing: `track_link`, `audio_features`, `track_reference`, and `lyrics`.

# %%
def load_table(table_name):
    return spark.read.jdbc(
        url=jdbc_url,
        table=table_name,
        properties=connection_properties
    )

track_link_df = load_table("track_links")
audio_features_df = load_table("audio_features")
track_reference_df = load_table("track_reference")
lyrics_df = load_table("lyrics")

# %%
track_link_df.show(5, truncate=False)
# Out:
# +------------------------------------+--------------------------------------------------+---------------------------+-------------------------------------------+
# |musicbrainz_id                      |track_title                                       |channel                    |webpage_url                                |
# +------------------------------------+--------------------------------------------------+---------------------------+-------------------------------------------+
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|Ariana Grande - raindrops (an angel cried) (Audio)|Ariana Grande              |https://www.youtube.com/watch?v=-ZoJSLB2N18|
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|Through The Wire                                  |Kanye West                 |https://www.youtube.com/watch?v=AE8y25CcE6s|
# |012e3459-b54d-49e9-b48d-d0922d295c5a|I'll Cry Instead (Remastered 2009)                |The Beatles                |https://www.youtube.com/watch?v=zfnkMBOSIUQ|
# |013a7fe3-0113-4604-a295-f74a0b88bf05|Billy Joel - She's Always a Woman (Official Audio)|Billy Joel                 |https://www.youtube.com/watch?v=Cx3QmqV2pHg|
# |01564f1c-99b2-466a-a60d-4e22a5008525|KACEY MUSGRAVES - angel (official lyric video)    |K A C E Y M U S G R A V E S|https://www.youtube.com/watch?v=1jS-3q7qIfw|
# +------------------------------------+--------------------------------------------------+---------------------------+-------------------------------------------+
# only showing top 5 rows

# %%
audio_features_df.show(5, truncate=False)
# Out:
# +------------------------------------+------------------+-----------+------------------+------------------+------------+-------------------+--------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+--------------------+--------------------+-------------------+------------------+------------------+------------------+-------------------+-------------------+------------------+-------------------+--------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+-------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------------+
# |musicbrainz_id                      |duration_seconds  |sample_rate|tempo             |loudness          |danceability|energy             |speechiness         |acousticness      |instrumentalness  |liveness            |valence            |spectral_centroid |spectral_rolloff  |spectral_bandwidth|spectral_flatness   |zero_crossing_rate  |rms_energy         |tempo_variability |f0_mean           |mel_mean          |dynamic_range      |mfcc_1             |mfcc_2            |mfcc_3             |mfcc_4              |mfcc_5             |mfcc_6             |mfcc_7             |mfcc_8            |mfcc_9             |mfcc_10            |mfcc_11            |mfcc_12            |mfcc_13             |spectral_contrast_1|spectral_contrast_2|spectral_contrast_3|spectral_contrast_4|spectral_contrast_5|spectral_contrast_6|spectral_contrast_7|chroma_cens_1      |chroma_cens_2      |chroma_cens_3      |chroma_cens_4      |chroma_cens_5      |chroma_cens_6      |chroma_cens_7      |chroma_cens_8      |chroma_cens_9      |chroma_cens_10     |chroma_cens_11     |chroma_cens_12     |tonnetz_1           |tonnetz_2           |tonnetz_3            |tonnetz_4            |tonnetz_5            |tonnetz_6           |
# +------------------------------------+------------------+-----------+------------------+------------------+------------+-------------------+--------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+--------------------+--------------------+-------------------+------------------+------------------+------------------+-------------------+-------------------+------------------+-------------------+--------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+-------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------------+
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|38.67285714285714 |44100      |129.19921875      |0.917354941368103 |0.5         |0.18948052823543549|0.066829026532488   |0.933170973467512 |0.7376519904762904|0.023771585896611214|0.2235630750656128 |2851.507127602107 |5338.83846507353  |2809.097894667404 |0.06149011850357056 |0.066829026532488   |0.18948052823543549|12.293727096928214|359.4350466702453 |9.648205757141113 |0.49367111921310425|-260.8947448730469 |81.00894165039062 |-58.195499420166016|-0.44929876923561096|-16.097623825073242|-10.797815322875977|-25.40866470336914 |-1.54789137840271 |-21.260398864746094|-16.773786544799805|4.776501655578613  |-7.276707172393799 |-18.568099975585938 |11.090056271775321 |15.688510696140813 |22.036188711764506 |23.31060123403226  |23.23934853611265  |26.298185710277103 |36.266885550614916 |0.17126603424549103|0.38616085052490234|0.1142386943101883 |0.10084984451532364|0.07325337082147598|0.17409966886043549|0.21019870042800903|0.12412311136722565|0.3445555567741394 |0.14665035903453827|0.2627240717411041 |0.19260716438293457|-0.21166671933821746|-0.1595589166506849 |-0.15586686545371464 |-0.019993984945161025|0.009904069759401739 |-0.05472993717994279|
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|221.22666666666666|44100      |109.95678191489361|1.234235405921936 |0.5         |0.290336549282074  |0.04171705363585673 |0.9582829463641432|0.6814166525315162|0.019878530874848366|0.5608453154563904 |2260.4441725273523|4952.586996318224 |2840.930677202912 |3.753877244889736E-4|0.04171705363585673 |0.290336549282074  |16.57327404397175 |450.2514358812312 |19.81159019470215 |0.6866095066070557 |-117.4135513305664 |149.0376739501953 |-26.541940689086914|47.5015869140625    |-4.812750816345215 |32.019596099853516 |5.087881565093994  |6.836766719818115 |8.09519100189209   |3.102311134338379  |6.586506366729736  |-0.4782048463821411|2.3451626300811768  |15.249802032059758 |10.97823430933141  |15.399373791987706 |17.825354188903024 |18.47567504764066  |17.782435273141918 |41.57619044143334  |0.20397187769412994|0.1746579110622406 |0.19566664099693298|0.1562146097421646 |0.244064062833786  |0.18000075221061707|0.1809757947921753 |0.3379957377910614 |0.4562852680683136 |0.4432307481765747 |0.2651456296443939 |0.20478293299674988|0.03554967786795201 |0.014456885836112019|-0.049916819996820995|0.08735894721365019  |-0.007599719134726644|-0.00814198684256462|
# |012e3459-b54d-49e9-b48d-d0922d295c5a|105.98666666666666|44100      |97.50884433962264 |1.1968110799789429|0.5         |0.1684114933013916 |0.08874839325569614 |0.9112516067443038|0.6507927257797893|0.003037161659449339|0.46500563621520996|3886.9189156410553|8223.18329850271  |3976.2761033743723|0.007323886267840862|0.08874839325569614 |0.1684114933013916 |13.248876874561143|158.17643998045085|5.081244945526123 |0.3124934732913971 |-97.93560028076172 |113.87683868408203|-34.519935607910156|39.20465850830078   |-9.346450805664062 |30.32764434814453  |-12.537554740905762|20.183969497680664|-11.23804759979248 |11.11453628540039  |-2.7775309085845947|13.694206237792969 |-0.24835437536239624|16.156674273171205 |10.870645070724681 |15.563330522687465 |17.39750647782178  |17.385070064003788 |17.245968637415384 |44.28506141413475  |0.23794449865818024|0.188299298286438  |0.33633849024772644|0.13088740408420563|0.20528991520404816|0.13919997215270996|0.21387799084186554|0.3786609470844269 |0.23166391253471375|0.300234317779541  |0.22393494844436646|0.26729223132133484|0.16127545674617386 |0.08779004689843219 |0.08013318488640618  |-0.03773352977461558 |0.009615629169068768 |-0.01796308953302726|
# |013a7fe3-0113-4604-a295-f74a0b88bf05|203.09333333333333|44100      |117.45383522727273|0.8493362069129944|0.5         |0.12357266992330551|0.033946404392220186|0.9660535956077798|0.8456417181947923|0.003631097264587879|0.3936772644519806 |1557.7778579720496|2939.1468285778337|2113.051716863804 |0.007841975428164005|0.033946404392220186|0.12357266992330551|13.52478906672504 |178.3984258805392 |3.5486507415771484|0.33590441942214966|-233.62767028808594|179.98806762695312|-16.758886337280273|23.79633140563965   |3.9907772541046143 |19.681997299194336 |-1.5064228773117065|3.939565420150757 |4.372893810272217  |-5.751853942871094 |2.004439353942871  |-1.2956733703613281|-0.6730408668518066 |18.58328153655552  |12.897008887535552 |17.359551177026027 |19.515753872601987 |19.67693981639007  |20.377055579095344 |38.24650783292901  |0.16196684539318085|0.08279954642057419|0.19812911748886108|0.344964861869812  |0.103155717253685  |0.24747006595134735|0.1397911012172699 |0.29509082436561584|0.23164494335651398|0.14267773926258087|0.3653663396835327 |0.10178152471780777|-0.18798410778553146|0.1555123912859923  |0.12495682959908137  |-0.0790922667822292  |0.023874527364980785 |0.00564960710441886 |
# |01564f1c-99b2-466a-a60d-4e22a5008525|151.74401360544218|44100      |123.046875        |0.8899034261703491|0.5         |0.19522807002067566|0.026959430705378318|0.9730405692946217|0.8156021586000006|0.009259252808988094|0.32976028323173523|1549.756164344242 |3199.124612692219 |2260.723415802317 |0.0809452161192894  |0.026959430705378318|0.19522807002067566|13.926631041274643|327.5694062550208 |9.164080619812012 |0.4019536077976227 |-216.2490692138672 |157.3820343017578 |-10.094855308532715|46.30569076538086   |-0.9183177947998047|10.434310913085938 |1.5026605129241943 |6.144595623016357 |0.13680212199687958|-3.0384745597839355|5.095779895782471  |-6.738167762756348 |0.7524964213371277  |16.225565686501554 |13.14527830378949  |18.02657299044107  |19.230769543332944 |18.54255290669634  |18.228109859652378 |36.44080006915015  |0.05619880557060242|0.20522958040237427|0.09205300360918045|0.2764616310596466 |0.27648699283599854|0.11025398969650269|0.33058878779411316|0.17098914086818695|0.2805677652359009 |0.0654573142528534 |0.17223447561264038|0.29659873247146606|-0.06704598852242809|-0.24252711132820812|0.12032933925735131  |0.021799544713932785 |0.00956078829793277  |-0.0098011373992262 |
# +------------------------------------+------------------+-----------+------------------+------------------+------------+-------------------+--------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+--------------------+--------------------+-------------------+------------------+------------------+------------------+-------------------+-------------------+------------------+-------------------+--------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+-------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------------+
# only showing top 5 rows

# %%
track_reference_df.show(5, truncate=False)
# Out:
# +------------------------------------+--------------------------+---------------+------------------------------------+---------------------------------------------------------+------------------------------------+------------+-------+------+
# |musicbrainz_id                      |title                     |artist         |artist_id                           |album                                                    |album_id                            |release_date|country|length|
# +------------------------------------+--------------------------+---------------+------------------------------------+---------------------------------------------------------+------------------------------------+------------+-------+------+
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|raindrops (an angel cried)|Ariana Grande  |f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387|sweetener / thank u, next tour - live at Coachella 2019  |6cd36f2a-0c90-45ea-b63b-0e922f1df4ba|2019-04-19  |XW     |36000 |
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|Through the Wire          |Ye             |164f0d73-1234-4e2c-8743-d77bf2191051|BET Awards: '04 Nominees                                 |d9f9fa38-f06e-4d22-abf8-73b60983ef8f|2004-01-01  |US     |270386|
# |012e3459-b54d-49e9-b48d-d0922d295c5a|I'll Cry Instead          |The Beatles    |b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d|UK EP Collection, Volume 1                               |51443d4d-fdb8-4d4e-8b61-58237764e6ae|2000-01-01  |XW     |107000|
# |013a7fe3-0113-4604-a295-f74a0b88bf05|She’s Always a Woman      |Billy Joel     |64b94289-9474-4d43-8c93-918ccc1920d1|Retold, Volume 3: Souvenir of a Stranger at the Turnstile|c5c69643-b9d3-446b-a773-57747bc1ad08|1995-01-01  |US     |120560|
# |01564f1c-99b2-466a-a60d-4e22a5008525|angel                     |Kacey Musgraves|d1393ecb-431b-4fde-a6ea-d769f2f040cb|star‐crossed                                             |80ec0d1a-00cf-465c-b832-26f15b558b57|2021-09-10  |NULL   |140000|
# +------------------------------------+--------------------------+---------------+------------------------------------+---------------------------------------------------------+------------------------------------+------------+-------+------+
# only showing top 5 rows

# %%
lyrics_df.show(5, truncate=False)
# Out:
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |musicbrainz_id                      |genius_lyrics                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|94 Contributors\nTranslations\nPolski\nEspañol\nРусский\nRomână\nPortuguês\nItaliano\nHebrew\nDeutsch\nFrançais\nNederlands\nDansk\nraindrops (an angel cried) Lyrics\nThe a capella “raindrops (an angel cried)” is the introduction to Ariana Grande’s fourth studio album, Sweetener. This song is a cover of The Four Seasons' “An Angel Cried.”\n\nThe song was first teased in her… \nRead More\n \n[Verse]\nWhen raindrops fell down from the sky\nThe day you left me, an angel cried\nOh, she cried\nAn angel cried, she cried                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|275 Contributors\nTranslations\nPortuguês\nРусский\nFrançais\nEspañol\nThrough the Wire Lyrics\nOn October 23, 2002, Kanye crashed his car and fractured his jaw. The “Through the Wire” title comes from the fact that Kanye recorded the original version while his mouth was still wired shut. The track… \nRead More\n \n[Intro: Kanye West & \nChaka Khan\n]\n(\nThrough the test of time\n)\nYo, Gee, they can't stop me from rappin', can they?\nCan they, Hop?\n[Chorus: \nChaka Khan\n]\nThrough the fire, to the limit, to the wall\nFor a chance to be with you, I'd gladly risk it all\nThrough the fire, through whatever, come what may\nFor a chance at loving you, I'd take it all the way\nRight down to the wire, even through the fire\n[Post-Chorus: Kanye West]\nI spit it through the wire, man\nThere's too much stuff on my heart right now, man\nI'd gladly risk it all right now\nIt's a life-or-death situation, man\nY'all, y'all don't really understand how I feel right now, man\nIt's your boy, Kanye To The…\nChi-Town, what's goin' on?\nUh-huh, yeah, yeah\n[Verse 1: Kanye West]\nI drink a Boost for breakfast, an Ensure for dessert\nSomebody order pancakes, I'll just sip the sizzurp\nThat right there could drive a sane man berserk\nNot to worry, Mr. H-to-the-Izzo's back to wizzerk\nHow do you console my mom, or give her light support\nTellin' her her son's on life support?\nAnd just imagine how my girl feel\nOn the plane scared as hell that her guy look like Emmett Till\nShe was with me before the deal, she'd been tryna be mine\nShe a Delta, so she \nbeen\n throwin' that Dynasty sign\nNo use in me tryna be lyin', I've been tryna be signed\nTryin' to be a millionaire; ha – I used two lifelines\nIn the same hospital where Biggie Smalls died\nThe doctor said I had blood clots, but I ain't Jamaican, man\nStory on MTV and I ain't tryna make Da Band\nI swear, this, right here, history in the makin', man[Chorus: Chaka Khan]\nThrough the fire, to the limit, to the wall\nFor a chance to be with you, I'd gladly risk it all\nThrough the fire, through whatever, come what may\nFor a chance at loving you, I'd take it all the way\nRight down to the wire, even through the fire\n[Post-Chorus: Kanye West]\nI really apologize to everyone right now\nIf it's unclear at all, man\nThey got my mouth wired shut\nFor like… I dunno, the doctor said, like, six weeks\nY'know, he had--I had reconstructive surgery on my jaw\nI looked in the mirror–half my jaw was in the back of my mouth, man\nI couldn't believe it\nBut I'm still here for y'all right now, man\nThis what I got to say right here, dawg\nYeah, turn me up, yeah, uh\n[Verse 2: Kanye West]\nWhat if somebody from the Chi' that was ill got a deal\nOn the hottest rap label around?\nBut he wasn't talkin' 'bout coke and birds, \nIt was more like spoken word, 'cept he's really puttin' it down?\nAnd he explained the story 'bout how Blacks came from glory\nAnd what we need to do in the game\nGood dude, bad night, right place, wrong time\nIn the blink of a eye, his whole life changed\nIf you could feel how my face felt, \nYou would know how Mase felt (Mason Betha!)\nThank \nGod\n I ain't too cool for the safe belt\nI swear to \nGod\n, driver two wanna sue\nI got a lawyer for the case, to keep what's in my safe–safe\nMy dawgs couldn't tell if I…\nI looked like Tom Cruise in \nVanilla Sky\n,\n \nit was televised\n"There's been an accident," like GEICO\nThey thought I was burnt up like Pepsi did Michael\nI must got a angel, 'cause look how death missed his ass\nUnbreakable\n, what you thought, they call me Mr. Glass?\nLook back on my life like the Ghost of Christmas Past\n (Uh-huh)\nToys "R" Us where I used to spend that Christmas cash\nAnd I still won't grow up, I'm a grown-ass kid\nSwear I should be locked up for stupid [shit] that I did\nBut I'm a champion, so I turned tragedy to triumph\n (Uh-huh! Yeah!)\nMake music that's fire,\n \nspit my soul through the wire\n (Woo!)[Chorus: Chaka Kh ...
# |012e3459-b54d-49e9-b48d-d0922d295c5a|31 Contributors\nI’ll Cry Instead Lyrics\nJohn Lennon wrote the song for the “break-out” sequence in the film. The song was recorded on 1 June 1964 in two sections, A and B, which could then be spliced together at a later date to achieve the required… \nRead More\n \n[Verse 1]\nI've got every reason on Earth to be mad\n'Cause I've just lost the only girl I had\nIf I could get my way\nI'd get myself locked up today\nBut I can't so I'll cry instead\n[Verse 2]\nI've got a chip on my shoulder that's bigger than my feet\nI can't talk to people that I meet\nIf I could see you now\nI'd try to make you sad somehow\nBut I can't so I'll cry instead\n[Bridge]\nDon't wanna cry when there's people there\nI get shy when they start to stare\nI'm gonna hide myself away, hey\nBut I'll come back again someday\n[Verse 3]\nAnd when I do, you better hide all the girls\nI'm gonna break their hearts all 'round the world\nYes, I'm gonna break 'em in two\nAnd show you what your loving man can do\nUntil then, I'll cry instead[Bridge]\nDon't wanna cry when there's people there\nI get shy when they start to stare\nI'm gonna hide myself away, hey\nBut I'll come back again someday\n[Verse 3]\nAnd when I do, you better hide all the girls\n'Cause I'm gonna break their hearts all 'round the world\nYes, I'm gonna break 'em in two\nAnd show you what your loving man can do\nUntil then, I'll cry instead                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# |013a7fe3-0113-4604-a295-f74a0b88bf05|37 Contributors\nShe’s Always a Woman Lyrics\n“She’s Always a Woman” is a song from Billy Joel’s 1977 album The Stranger. It is a love song about a modern woman, with whom he falls in love for her quirks as well as her flaws, regardless of how… \nRead More\n \n[Verse 1]\nShe can kill with a smile\nShe can wound with her eyes\nAnd she can ruin your faith with her casual lies\nAnd she only reveals\nWhat she wants you to see\nShe hides like a child\nBut she's always a woman to me\n[Verse 2]\nShe can lead you to love\nShe can take you or leave you\nShe can ask for the truth\nBut she'll never believe you\nAnd she'll take what you give her\nAs long as it's free\nYeah, she steals like a thief\nBut she's always a woman to me\n[Chorus]\nOh, she takes care of herself\nShe can wait if she wants\nShe's ahead of her time\nOh, and she never gives out\nAnd she never gives in\nShe just changes her mind[Verse 3]\nAnd she'll promise you more\nThan the Garden of Eden\nThen she'll carelessly cut you\nAnd laugh while you're bleedin'\nBut she'll bring out the best\nAnd the worst you can be\nBlame it all on yourself\nCause she's always a woman to me\n[Interlude]\nMmm mmm\nMmm mmm mmm mmm mm\n[Chorus]\nOh, she takes care of herself\nShe can wait if she wants\nShe's ahead of her time\nOh, and she never gives out\nAnd she never gives in\nShe just changes her mind\n[Verse 4]\nShe is frequently kind\nAnd she's suddenly cruel\nShe can do as she pleases\nShe's nobody's fool\nBut she can't be convicted\nShe's earned her degree\nAnd the most she will do\nIs throw shadows at you\nBut she's always a woman to me[Outro]\nMmm mm, mmm mm\nMmm mmm mmm mmm mmm                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |01564f1c-99b2-466a-a60d-4e22a5008525|15 Contributors\n​angel Lyrics\n[Verse 1]\nIf I was an angel, I wouldn't have to try\nSo hard to save you or show you how to fly\nIf I was an angel, I wouldn't get so mad\nIt'd be easy to be grateful for everything I have\n[Pre-Chorus]\nYou'd only get the best of me\n[Chorus]\nI'd pull you out of the darkness\nKeep you out of the rain\nEverything would be better\nI'd never have to change\nI'd never have to change\n[Verse 2]\nIf I was an angel, I'd use only pretty words\nAnd when I'm talking to you, it would never hurt\n[Pre-Chorus]\nYou'd only get the best of me\nI'd nevеr make you wanna leave\n[Chorus]\nI'd pull you out of thе darkness\nKeep you out of the rain\nEverything would be better\nYou'd never have to change\nYou'd never have to change\nBut something's gotta change[Chorus]\nI'd pull you out of the darkness\nAlways keep you safe\nEverything would be better\nI'd never have to change\nI'd never have to change                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %% [markdown]
# ## 5. Show Sample Records
# Let's display a few records from each table to get an understanding of their structure.

# %%
track_link_df.join(track_reference_df, on="musicbrainz_id").select("track_title", "artist", "album").show(5, truncate=False)
# Out:
# +------------------------------------------------------------------+---------------------+---------------------+
# |track_title                                                       |artist               |album                |
# +------------------------------------------------------------------+---------------------+---------------------+
# |Madison Beer - King of Everything (Official Lyric Video)          |Madison Beer         |Silence Between Songs|
# |Ariana Grande - the light is coming ft. Nicki Minaj               |Ariana Grande        |Sweetener            |
# |Bitch Niggaz                                                      |Dr. Dre              |2001: Instrumentals  |
# |Harry Styles - As It Was (Official Video)                         |Harry Styles         |As It Was            |
# |Piotr Ilich Tchaikovsky - The Nutcracker, Dance of the Reed Flutes|Пётр Ильич Чайковский|100 Hits: Classical  |
# +------------------------------------------------------------------+---------------------+---------------------+
# only showing top 5 rows

# %% [markdown]
# ## Join track metadata with artist and album
# Join `track_link` with `track_reference` to retrieve track title, artist, and album info.

# %%
audio_features_df.orderBy(col("energy").desc()).select("musicbrainz_id", "energy").show(5, truncate=False)
# Out:
# +------------------------------------+-------------------+
# |musicbrainz_id                      |energy             |
# +------------------------------------+-------------------+
# |635ca7c5-1ef5-4acf-894f-aa6d6eda4e6b|0.38299816846847534|
# |a3b54a75-8fc8-4b18-916a-8ac951c0c7ed|0.37580251693725586|
# |2e8f9c02-ebc6-4098-84cb-224d46e46ef8|0.3742404580116272 |
# |196a9bc5-6468-455e-a602-00f923b34198|0.369456022977829  |
# |d8ccf243-a78b-4397-b331-18da5ecc5759|0.3678611218929291 |
# +------------------------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ## Combine track metadata with energy and valence scores
# Join track reference, audio features, and lyrics to get combined metadata with energy and valence.

# %%
track_reference_df \
    .join(audio_features_df, on="musicbrainz_id") \
    .join(lyrics_df, on="musicbrainz_id") \
    .select("title", "artist", "energy", "valence") \
    .show(5, truncate=False)
# Out:
# +------------------------+---------------------+--------------------+-------------------+
# |title                   |artist               |energy              |valence            |
# +------------------------+---------------------+--------------------+-------------------+
# |King of Everything      |Madison Beer         |0.18618640303611755 |0.38116011023521423|
# |the light is coming     |Ariana Grande        |0.29869845509529114 |0.5234681963920593 |
# |Bitch Niggaz            |Dr. Dre              |0.26235342025756836 |0.4938736855983734 |
# |As It Was               |Harry Styles         |0.34368205070495605 |0.397524356842041  |
# |Dance of the Reed Flutes|Пётр Ильич Чайковский|0.018364010378718376|0.3955545723438263 |
# +------------------------+---------------------+--------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ## Average tempo grouped by country
# Compute the average tempo of tracks for each country.

# %%
track_reference_df \
    .join(audio_features_df, on="musicbrainz_id") \
    .groupBy("country") \
    .agg(avg("tempo") \
    .alias("avg_tempo")) \
    .orderBy(desc("avg_tempo")) \
    .show(5, truncate=False)
# Out:
# +-------+------------------+
# |country|avg_tempo         |
# +-------+------------------+
# |BH     |139.6748310810811 |
# |CZ     |139.02354958751792|
# |NL     |132.51201923076923|
# |CA     |131.91143939994564|
# |TW     |129.19921875      |
# +-------+------------------+
# only showing top 5 rows

# %% [markdown]
# ## Happy and danceable tracks
# Filter tracks with valence > 0.7 and danceability > 0.7.

# %%
audio_features_df \
    .filter((col("valence") > 0.5) & (col("danceability") >= 0.5)) \
    .select("musicbrainz_id", "valence", "danceability") \
    .orderBy("valence", ascending=False) \
    .show(10, truncate=False)
# Out:
# +------------------------------------+------------------+------------+
# |musicbrainz_id                      |valence           |danceability|
# +------------------------------------+------------------+------------+
# |bdb0435f-9d43-4d62-a1c7-35ef01b82ba0|0.663307249546051 |0.5         |
# |edcf70c1-2d55-4430-a46c-c3b113bd221b|0.6343459486961365|0.5         |
# |7362fccc-b012-4541-9792-9f359c1881a0|0.6107845902442932|0.5         |
# |1a1519e4-8184-4015-91de-28c767b7f523|0.6073976159095764|0.5         |
# |814f3f62-db19-469d-a96b-12f4a1b0adc3|0.6005522012710571|0.5         |
# |516bf889-cdd2-4d55-b9ab-8f5c9cdb7de9|0.5983216166496277|0.5         |
# |cfc5f79b-b25b-4309-8ac4-816463323472|0.5980272889137268|0.5         |
# |13c5ba92-c6dd-4c8c-88ae-5810626edd6a|0.5961501598358154|0.5         |
# |2bf5444e-9d88-4b34-aec0-5a423b4d348a|0.5958881378173828|0.5         |
# |6cf20e9f-a788-4291-90a0-ffd8ffc9bf60|0.5939623117446899|0.5         |
# +------------------------------------+------------------+------------+
# only showing top 10 rows

# %% [markdown]
# ## Count of Tracks per Artist
# Display artists and their respective track counts in descending order

# %%
track_reference_df \
    .groupBy("artist") \
    .count() \
    .orderBy(desc("count")) \
    .show(5, truncate=False)
# Out:
# +-------------+-----+
# |artist       |count|
# +-------------+-----+
# |Taylor Swift |72   |
# |Ariana Grande|72   |
# |Beyoncé      |54   |
# |Justin Bieber|48   |
# |The Beatles  |44   |
# +-------------+-----+
# only showing top 5 rows

# %% [markdown]
# ## Tracks with available Genius lyrics
# Filter tracks that have available lyrics from Genius platform.

# %%
lyrics_df \
    .filter(col("genius_lyrics").isNotNull()) \
    .select("musicbrainz_id", "genius_url") \
    .show(5, truncate=False)
# Out:
# +------------------------------------+----------------------------------------------------------------+
# |musicbrainz_id                      |genius_url                                                      |
# +------------------------------------+----------------------------------------------------------------+
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|https://genius.com/Ariana-grande-raindrops-an-angel-cried-lyrics|
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|https://genius.com/Kanye-west-through-the-wire-lyrics           |
# |012e3459-b54d-49e9-b48d-d0922d295c5a|https://genius.com/The-beatles-ill-cry-instead-lyrics           |
# |013a7fe3-0113-4604-a295-f74a0b88bf05|https://genius.com/Billy-joel-shes-always-a-woman-lyrics        |
# |01564f1c-99b2-466a-a60d-4e22a5008525|https://genius.com/Kacey-musgraves-angel-lyrics                 |
# +------------------------------------+----------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ## Count of Unique Artists per Country
# Get the count of unique artists available per country

# %%
track_reference_df \
    .groupBy("country") \
    .agg(countDistinct("artist").alias("unique_artists")) \
    .orderBy(desc("unique_artists")) \
    .show(5, truncate=False)
# Out:
# +-------+--------------+
# |country|unique_artists|
# +-------+--------------+
# |NULL   |33            |
# |XW     |31            |
# |US     |27            |
# |GB     |18            |
# |XE     |12            |
# +-------+--------------+
# only showing top 5 rows

# %% [markdown]
# ## Count of Tracks per Release Date
# Count the tracks for each release date and order them in descending order

# %%
track_reference_df \
    .groupBy("release_date") \
    .count() \
    .orderBy(desc("count")) \
    .show(5, truncate=False)
# Out:
# +------------+-----+
# |release_date|count|
# +------------+-----+
# |null        |80   |
# |2024-03-29  |25   |
# |2025-03-14  |24   |
# |2022-03-16  |18   |
# |2005-01-01  |17   |
# +------------+-----+
# only showing top 5 rows

# %% [markdown]
# ## Top 5 most danceable tracks
# Retrieve the most danceable tracks ordered by danceability.

# %%
audio_features_df \
    .orderBy(desc("danceability")) \
    .select("musicbrainz_id", "danceability") \
    .show(5, truncate=False)
# Out:
# +------------------------------------+------------+
# |musicbrainz_id                      |danceability|
# +------------------------------------+------------+
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|0.5         |
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|0.5         |
# |012e3459-b54d-49e9-b48d-d0922d295c5a|0.5         |
# |013a7fe3-0113-4604-a295-f74a0b88bf05|0.5         |
# |01564f1c-99b2-466a-a60d-4e22a5008525|0.5         |
# +------------------------------------+------------+
# only showing top 5 rows

# %% [markdown]
# ## Count of tracks grouped by sample rate
# Group tracks by their sample rate and count occurrences.

# %%
audio_features_df \
    .groupBy("sample_rate") \
    .count() \
    .orderBy(desc("count")) \
    .show(5, truncate=False)
# Out:
# +-----------+-----+
# |sample_rate|count|
# +-----------+-----+
# |44100      |1093 |
# +-----------+-----+

# %% [markdown]
# ## Tracks released in the US
# Filter tracks that are marked with country as US.

# %%
track_reference_df \
    .filter(col("country") == "US") \
    .select("title", "artist") \
    .show(10, truncate=False)
# Out:
# +------------------------+------------+
# |title                   |artist      |
# +------------------------+------------+
# |Through the Wire        |Ye          |
# |She’s Always a Woman    |Billy Joel  |
# |SWEET ★ HONEY ★ BUCKIIN’|Beyoncé     |
# |Touch the Sky           |Ye          |
# |STOP TRYING TO BE GOD   |Travis Scott|
# |Let Down                |Radiohead   |
# |The National Anthem     |Radiohead   |
# |Three Empty Words       |Shawn Mendes|
# |Fuck You                |Dr. Dre     |
# |Electioneering          |Radiohead   |
# +------------------------+------------+
# only showing top 10 rows

# %% [markdown]
# ## Average MFCC 1 feature per track
# Compute the average MFCC 1 value grouped by track.

# %%
audio_features_df \
    .groupBy("musicbrainz_id") \
    .agg(avg("mfcc_1").alias("avg_mfcc_1")) \
    .orderBy(desc("avg_mfcc_1")) \
    .show(5, truncate=False)
# Out:
# +------------------------------------+-------------------+
# |musicbrainz_id                      |avg_mfcc_1         |
# +------------------------------------+-------------------+
# |4807e1a1-8766-44e3-9884-e586d7a45ef8|-18.950777053833008|
# |ea2915f0-b307-448f-9081-b5051fd820f6|-37.45595169067383 |
# |27659585-8b8a-4720-abb8-1b59826552e6|-38.347564697265625|
# |2bbd29fa-b951-4e78-9e24-85918142f1f1|-39.8458137512207  |
# |2e8f9c02-ebc6-4098-84cb-224d46e46ef8|-42.14936828613281 |
# +------------------------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ## Max and min tempo per track
# Get max and min tempo for each track.

# %%
audio_features_df \
    .groupBy("musicbrainz_id") \
    .agg(spark_max("tempo").alias("max_tempo"), spark_min("tempo").alias("min_tempo")) \
    .show(5)
# Out:
# +--------------------+------------------+------------------+
# |      musicbrainz_id|         max_tempo|         min_tempo|
# +--------------------+------------------+------------------+
# |6ade8d7b-0206-483...|         147.65625|         147.65625|
# |775290ba-0c56-480...| 99.38401442307692| 99.38401442307692|
# |9d2d9942-d66b-40c...|166.70866935483872|166.70866935483872|
# |e0bf757c-e18c-47a...|         114.84375|         114.84375|
# |16c9e040-c6d3-458...| 139.6748310810811| 139.6748310810811|
# +--------------------+------------------+------------------+
# only showing top 5 rows

# %% [markdown]
# ## Tracks released after 2015
# Filter tracks released after Jan 1, 2015.

# %%
track_reference_df \
    .filter(col("release_date") > "2015-01-01") \
    .select("title", "artist") \
    .show(5, truncate=False)
# Out:
# +--------------------------+-----------------------+
# |title                     |artist                 |
# +--------------------------+-----------------------+
# |raindrops (an angel cried)|Ariana Grande          |
# |angel                     |Kacey Musgraves        |
# |Where the Money Flows     |Peter Cat Recording Co.|
# |SWEET ★ HONEY ★ BUCKIIN’  |Beyoncé                |
# |King Kunta                |Kendrick Lamar         |
# +--------------------------+-----------------------+
# only showing top 5 rows

# %% [markdown]
# ## Long tracks with duration > 300 seconds
# Filter tracks longer than 300 seconds.

# %%
track_reference_df \
    .filter(col("length") > 300) \
    .select("title", "length") \
    .show(5, truncate=False)
# Out:
# +--------------------------+------+
# |title                     |length|
# +--------------------------+------+
# |raindrops (an angel cried)|36000 |
# |Through the Wire          |270386|
# |I'll Cry Instead          |107000|
# |She’s Always a Woman      |120560|
# |angel                     |140000|
# +--------------------------+------+
# only showing top 5 rows

# %% [markdown]
# ## Tracks with high speechiness (> 0.2)
# Filter tracks where speechiness is greater than 0.2.

# %%
audio_features_df \
    .filter(col("speechiness") > 0.2) \
    .select("musicbrainz_id", "speechiness") \
    .show(5, truncate=False)
# Out:
# +------------------------------------+------------------+
# |musicbrainz_id                      |speechiness       |
# +------------------------------------+------------------+
# |2421ac91-d401-4c69-9a4c-feca38b95d71|0.2122621617854542|
# |b4f22410-ef06-4d44-b789-f32c185acbad|0.4694865198610758|
# +------------------------------------+------------------+

# %% [markdown]
# ## Instrumental tracks (instrumentalness > 0.8)
# Filter tracks where instrumentalness is greater than 0.8.

# %%
audio_features_df \
    .filter(col("instrumentalness") > 0.8) \
    .select("musicbrainz_id", "instrumentalness") \
    .show(5, truncate=False)
# Out:
# +------------------------------------+------------------+
# |musicbrainz_id                      |instrumentalness  |
# +------------------------------------+------------------+
# |013a7fe3-0113-4604-a295-f74a0b88bf05|0.8456417181947923|
# |01564f1c-99b2-466a-a60d-4e22a5008525|0.8156021586000006|
# |02159dd4-018a-4264-acca-19d2edc233d2|0.843158409831264 |
# |039326dc-e853-4de8-84c5-dd91c31d4256|0.8024577167645605|
# |0501d394-60d9-4d55-8415-ce420dad9b54|0.8600274110418155|
# +------------------------------------+------------------+
# only showing top 5 rows

# %% [markdown]
# ## Tracks with available Last.fm wiki summary
# Filter tracks with a non-null wiki summary from Last.fm.

# %%
lyrics_df \
    .filter(col("lastfm_wiki_summary").isNotNull()) \
    .select("musicbrainz_id", "lastfm_wiki_summary") \
    .show(5, truncate=False)
# Out:
# +------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |musicbrainz_id                      |lastfm_wiki_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |00b1397d-7f3e-4c59-bb42-ccd7fa17ee10|"Raindrops (An Angel Cried)" (stylized in all lowercase) is the opening track from Ariana Grande's fourth studio album, Sweetener (2018). It was released through Republic Records on August 17, 2018.\nA live version of the song is featured on K Bye for Now (SWT Live), which was released on December 23, 2019. <a href="http://www.last.fm/music/Ariana+Grande/_/raindrops+(an+angel+cried)">Read more on Last.fm</a>.                                                                                                                                                                                                      |
# |00c9dcab-4abf-47f5-9755-c5c805b779c7|"Through the Wire" is the lead single from  Kanye West's  debut album The College Dropout. It samples Chaka Khan's 1985 single "Through the Fire".\n\nIn 2002 while living in Los Angeles, Kanye was severely injured in a car accident and had to have his jaw wired shut. "Through the Wire" was originally recorded while West was in the hospital, and first appeared on the Get Well Soon mixtape.\n\n"Through the Wire" peaked at number 15 on the Billboard Hot 100 and received positive reviews from music critics. <a href="http://www.last.fm/music/Kanye+West/_/Through+the+Wire">Read more on Last.fm</a>.           |
# |012e3459-b54d-49e9-b48d-d0922d295c5a|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |013a7fe3-0113-4604-a295-f74a0b88bf05|"She's Always a Woman" is a She's Always a Woman by Billy Joel, released in 1977 as part of his breakthrough The Stranger. The single reached No. 17 on the US charts in October 1978, during a period when disco and punk rock were dominating the music scene. Billy Joel wrote this love song for his then-wife Elizabeth Weber, who was also his manager at the time. Weber had helped Joel recover from a disastrous contract with his first record label and played a crucial role in reviving his career in the mid-1970s. <a href="http://www.last.fm/music/Billy+Joel/_/She%27s+Always+a+Woman">Read more on Last.fm</a>.|
# |01564f1c-99b2-466a-a60d-4e22a5008525|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ## Musicbrainz ids with Zero Crossing Rate > 0.1
# Filter musicbrainz ids with zero crossing rate > 0.1

# %%
audio_features_df \
    .filter(col("zero_crossing_rate") > 0.1) \
    .select("musicbrainz_id", "zero_crossing_rate") \
    .show(5, truncate=False)
# Out:
# +------------------------------------+-------------------+
# |musicbrainz_id                      |zero_crossing_rate |
# +------------------------------------+-------------------+
# |04484bf3-6617-4a99-ae67-f15a440fcd6c|0.1010217366085619 |
# |0a62410e-efe8-4370-a4e5-e325a54fae16|0.13758016650732952|
# |1e79f696-1018-4cc5-b89d-2e9a03652ab0|0.11445952868852459|
# |2421ac91-d401-4c69-9a4c-feca38b95d71|0.2122621617854542 |
# |27659585-8b8a-4720-abb8-1b59826552e6|0.10341092069309507|
# +------------------------------------+-------------------+
# only showing top 5 rows
